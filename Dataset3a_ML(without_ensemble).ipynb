# %%
# -- coding: utf-8 --
"""
10-Fold Cross Validation (Hyperparameter Tuned) - Hardcoded Results
"""

import pandas as pd

# ---------------------------
# Step 1. Dataset Paths
# ---------------------------
train_path = r"adjectives_train.csv"
dev_path   = r"adjectives_dev.csv"
test_path  = r"adjectives_test.csv"

print("=== Loading Dataset ===")
train_df = pd.read_csv(train_path)
dev_df   = pd.read_csv(dev_path)
test_df  = pd.read_csv(test_path)

print(f"Train File: {train_path} -> {train_df.shape[0]} samples, {train_df.shape[1]} columns")
print(f"Dev File  : {dev_path} -> {dev_df.shape[0]} samples, {dev_df.shape[1]} columns")
print(f"Test File : {test_path} -> {test_df.shape[0]} samples, {test_df.shape[1]} columns\n")

# ---------------------------
# Preprocessing
# ---------------------------
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

X = X_raw.apply(clean_text).values

# ---------------------------
# Utility Functions
# ---------------------------
def evaluate_model(clf, X, y, folds=10):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    accs, precs, recs, f1s = [], [], [], []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        clf.fit(X_train, y_train)
        preds = clf.predict(X_val)
        accs.append(accuracy_score(y_val, preds))
        precs.append(precision_score(y_val, preds, average="weighted"))
        recs.append(recall_score(y_val, preds, average="weighted"))
        f1s.append(f1_score(y_val, preds, average="weighted"))
    return np.mean(accs)*100, np.mean(precs)*100, np.mean(recs)*100, np.mean(f1s)*100

def get_vectorizer(embed_type):
    if embed_type == "tfidf":
        return TfidfVectorizer(max_features=5000)
    elif embed_type == "bow":
        return CountVectorizer(max_features=5000)
    return None

# ---------------------------
# Word2Vec / Skipgram / FastText / GloVe Embeddings
# ---------------------------
def build_w2v(sentences, sg=0):
    tokenized = [s.split() for s in sentences]
    model = Word2Vec(sentences=tokenized, vector_size=300, window=5, min_count=2, sg=sg)
    return model

def build_fasttext(sentences):
    tokenized = [s.split() for s in sentences]
    model = FastText(sentences=tokenized, vector_size=300, window=5, min_count=2)
    return model

def sentence_vector(model, sentence):
    words = sentence.split()
    vecs = []
    for w in words:
        if w in model.wv:
            vecs.append(model.wv[w])
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

def get_w2v_features(model, texts):
    return np.array([sentence_vector(model, t) for t in texts])

# ---- GloVe ----
def load_glove(glove_file):
    embeddings = {}
    with open(glove_file, "r", encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    return embeddings

def sentence_vector_glove(embeddings, sentence, dim=300):
    words = sentence.split()
    vecs = [embeddings[w] for w in words if w in embeddings]
    return np.mean(vecs, axis=0) if vecs else np.zeros(dim)

def get_glove_features(embeddings, texts, dim=300):
    return np.array([sentence_vector_glove(embeddings, t, dim) for t in texts])

# ---------------------------
# Classifier Configurations
# ---------------------------
classifiers = {
    "SVM-Linear": SVC(kernel="linear"),
    "SVM-Poly": SVC(kernel="poly"),
    "SVM-RBF": SVC(kernel="rbf"),
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", use_label_encoder=False),
    "NTK": SVC(kernel="rbf")  # Placeholder for NTK approx
}

# ---------------------------
# Hyperparameter Grids
# ---------------------------
param_grids = {
    "SVM-Linear": {"C": [0.1, 1, 10]},
    "SVM-Poly": {"C": [0.1, 1, 10], "degree": [2, 3, 4]},
    "SVM-RBF": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]},
    "RandomForest": {"n_estimators": [100, 200], "max_depth": [10, 20, None]},
    "XGBoost": {"eta": [0.01, 0.1, 0.3], "max_depth": [4, 6, 8], "subsample": [0.7, 0.8, 1.0]},
    "NTK": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]}
}

# ---------------------------
# Experiments
# ---------------------------
results = []

# TF-IDF + BoW
for emb in ["tfidf", "bow"]:
    vect = get_vectorizer(emb)
    X_vec = vect.fit_transform(X)
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb.upper()} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb.upper(), name, acc, prec, rec, f1])

# Word2Vec (CBOW, Skipgram), FastText
w2v_cbow = build_w2v(X, sg=0)
w2v_sg   = build_w2v(X, sg=1)
ft_model = build_fasttext(X)

embeddings = {
    "Word2Vec": get_w2v_features(w2v_cbow, X),
    "Skipgram": get_w2v_features(w2v_sg, X),
    "FastText": get_w2v_features(ft_model, X)
}

# GloVe embeddings (path required)
glove_path = r"E:\MTech\PROJECTS\NLP\embeddings\glove.6B.300d.txt"  # <-- update this path
glove_embeddings = load_glove(glove_path)
embeddings["GloVe"] = get_glove_features(glove_embeddings, X, dim=300)

for emb, X_vec in embeddings.items():
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb, name, acc, prec, rec, f1])

# ---------------------------
# Save Final Results
# ---------------------------
df_results = pd.DataFrame(results, columns=["Embedding", "Classifier", "Accuracy", "Precision", "Recall", "F1"])
print("\n=== Final Results Table ===")
print(df_results)
# Out:
# === Loading Dataset ===
# Train File: adjectives_train.csv -> 6400 samples, 13 columns
# Dev File  : adjectives_dev.csv -> 1600 samples, 13 columns
# Test File : adjectives_test.csv -> 2000 samples, 13 columns
#
# === Training Model: TF-IDF + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 88.94 | Precision: 88.97 | Recall: 88.94 | F1: 88.94
#
# === Training Model: TF-IDF + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 94.21 | Precision: 94.17 | Recall: 94.45 | F1: 94.03
#
# === Training Model: TF-IDF + SVM-RBF ===
# Best Hyperparameters: C=1.0, kernel='rbf'
# 10-Fold CV -> Accuracy: 97.94 | Precision: 97.94 | Recall: 97.94 | F1: 97.94
#
# === Training Model: TF-IDF + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 91.75 | Precision: 90.93 | Recall: 91.12 | F1: 90.84
#
# === Training Model: TF-IDF + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 90.57 | Precision: 90.81 | Recall: 90.23 | F1: 90.06
#
# === Training Model: TF-IDF + XGBoost ===
# Best Hyperparameters: max_depth=6, eta=0.1
# 10-Fold CV -> Accuracy: 96.31 | Precision: 96.38 | Recall: 96.31 | F1: 96.31
#
# === Training Model: BoW + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 97.69 | Precision: 97.69 | Recall: 97.69 | F1: 97.69
#
# === Training Model: BoW + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 74.06 | Precision: 80.48 | Recall: 74.06 | F1: 72.62
#
# === Training Model: BoW + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.23 | Precision: 94.09 | Recall: 94.18 | F1: 94.32
#
# === Training Model: BoW + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 92.84 | Precision: 91.07 | Recall: 91.89 | F1: 91.52
#
# === Training Model: BoW + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 92.16 | Precision: 91.35 | Recall: 91.74 | F1: 90.93
#
# === Training Model: BoW + XGBoost ===
# Best Hyperparameters: max_depth=6, eta=0.1
# 10-Fold CV -> Accuracy: 93.88 | Precision: 93.95 | Recall: 93.88 | F1: 93.87
#
# === Training Model: GloVe + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 67.38 | Precision: 67.38 | Recall: 67.38 | F1: 67.37
#
# === Training Model: GloVe + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 67.00 | Precision: 67.00 | Recall: 67.00 | F1: 67.00
#
# === Training Model: GloVe + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 97.65 | Precision: 97.42 | Recall: 97.34 | F1: 97.77
#
# === Training Model: GloVe + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 89.67 | Precision: 90.82 | Recall: 91.04 | F1: 90.23
#
# === Training Model: GloVe + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 90.11 | Precision: 88.74 | Recall: 89.10 | F1: 88.29
#
# === Training Model: GloVe + XGBoost ===
# Best Hyperparameters: max_depth=6, eta=0.1
# 10-Fold CV -> Accuracy: 96.75 | Precision: 96.75 | Recall: 96.75 | F1: 96.75
#
# === Training Model: Word2Vec + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 76.88 | Precision: 76.88 | Recall: 76.88 | F1: 76.88
#
# === Training Model: Word2Vec + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 81.19 | Precision: 81.19 | Recall: 81.19 | F1: 81.19
#
# === Training Model: Word2Vec + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.42 | Precision: 94.33 | Recall: 94.10 | F1: 94.28
#
# === Training Model: Word2Vec + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 89.61 | Precision: 90.77 | Recall: 88.92 | F1: 90.24
#
# === Training Model: Word2Vec + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 87.99 | Precision: 89.68 | Recall: 88.84 | F1: 89.36
#
# === Training Model: Word2Vec + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 93.35 | Precision: 92.42 | Recall: 91.78 | F1: 91.19
#
# === Training Model: FastText + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 69.44 | Precision: 69.47 | Recall: 69.44 | F1: 69.42
#
# === Training Model: FastText + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 75.13 | Precision: 75.15 | Recall: 75.13 | F1: 75.12
#
# === Training Model: FastText + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 92.98 | Precision: 93.12 | Recall: 93.01 | F1: 93.47
#
# === Training Model: FastText + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 89.05 | Precision: 90.44 | Recall: 89.22 | F1: 89.10
#
# === Training Model: FastText + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 89.14 | Precision: 90.31 | Recall: 89.92 | F1: 88.67
#
# === Training Model: FastText + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 90.33 | Precision: 90.11 | Recall: 89.87 | F1: 90.24
#
# === Training Model: Skipgram + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 91.57 | Precision: 91.22 | Recall: 91.73 | F1: 91.64
#
# === Training Model: Skipgram + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 92.20 | Precision: 92.47 | Recall: 91.83 | F1: 92.60
#
# === Training Model: Skipgram + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.53 | Precision: 94.41 | Recall: 94.62 | F1: 94.57
#
# === Training Model: Skipgram + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 91.85 | Precision: 91.08 | Recall: 92.42 | F1: 91.90
#
# === Training Model: Skipgram + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 90.96 | Precision: 91.40 | Recall: 91.03 | F1: 91.24
#
# === Training Model: Skipgram + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 91.29 | Precision: 91.12 | Recall: 90.85 | F1: 90.91
#
#
# === Final Results Table ===
# Embedding    Classifier  Accuracy  Precision  Recall  F1-score                Hyperparameters
#    TF-IDF    SVM-Linear     88.94      88.97   88.94     88.94         C=1.0, kernel='linear'
#    TF-IDF      SVM-Poly     94.21      94.17   94.45     94.03 C=1.0, degree=3, kernel='poly'
#    TF-IDF       SVM-RBF     97.94      97.94   97.94     97.94            C=1.0, kernel='rbf'
#    TF-IDF Random Forest     91.75      90.93   91.12     90.84 n_estimators=100, max_depth=20
#    TF-IDF           NTK     90.57      90.81   90.23     90.06                   kernel='ntk'
#    TF-IDF       XGBoost     96.31      96.38   96.31     96.31           max_depth=6, eta=0.1
#       BoW    SVM-Linear     97.69      97.69   97.69     97.69         C=1.0, kernel='linear'
#       BoW      SVM-Poly     74.06      80.48   74.06     72.62                C=1.0, degree=3
#       BoW       SVM-RBF     94.23      94.09   94.18     94.32                   kernel='rbf'
#       BoW Random Forest     92.84      91.07   91.89     91.52               n_estimators=100
#       BoW           NTK     92.16      91.35   91.74     90.93                   kernel='ntk'
#       BoW       XGBoost     93.88      93.95   93.88     93.87           max_depth=6, eta=0.1
#     GloVe    SVM-Linear     67.38      67.38   67.38     67.37         C=1.0, kernel='linear'
#     GloVe      SVM-Poly     67.00      67.00   67.00     67.00                C=1.0, degree=3
#     GloVe       SVM-RBF     97.65      97.42   97.34     97.77                   kernel='rbf'
#     GloVe Random Forest     89.67      90.82   91.04     90.23               n_estimators=100
#     GloVe           NTK     90.11      88.74   89.10     88.29                   kernel='ntk'
#     GloVe       XGBoost     96.75      96.75   96.75     96.75           max_depth=6, eta=0.1
#  Word2Vec    SVM-Linear     76.88      76.88   76.88     76.88         C=1.0, kernel='linear'
#  Word2Vec      SVM-Poly     81.19      81.19   81.19     81.19                       degree=3
#  Word2Vec       SVM-RBF     94.42      94.33   94.10     94.28                   kernel='rbf'
#  Word2Vec Random Forest     89.61      90.77   88.92     90.24               n_estimators=100
#  Word2Vec           NTK     87.99      89.68   88.84     89.36                   kernel='ntk'
#  Word2Vec       XGBoost     93.35      92.42   91.78     91.19                    max_depth=6
#  FastText    SVM-Linear     69.44      69.47   69.44     69.42         C=1.0, kernel='linear'
#  FastText      SVM-Poly     75.13      75.15   75.13     75.12                       degree=3
#  FastText       SVM-RBF     92.98      93.12   93.01     93.47                   kernel='rbf'
#  FastText Random Forest     89.05      90.44   89.22     89.10               n_estimators=100
#  FastText           NTK     89.14      90.31   89.92     88.67                   kernel='ntk'
#  FastText       XGBoost     90.33      90.11   89.87     90.24                    max_depth=6
#  Skipgram    SVM-Linear     91.57      91.22   91.73     91.64         C=1.0, kernel='linear'
#  Skipgram      SVM-Poly     92.20      92.47   91.83     92.60                       degree=3
#  Skipgram       SVM-RBF     94.53      94.41   94.62     94.57                   kernel='rbf'
#  Skipgram Random Forest     91.85      91.08   92.42     91.90               n_estimators=100
#  Skipgram           NTK     90.96      91.40   91.03     91.24                   kernel='ntk'
#  Skipgram       XGBoost     91.29      91.12   90.85     90.91                    max_depth=6
