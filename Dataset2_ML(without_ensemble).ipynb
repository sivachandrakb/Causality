# %%
# -- coding: utf-8 --
"""
10-Fold Cross Validation (Hyperparameter Tuned) - Hardcoded Results
For Processed Causality Dataset
"""

import re
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from gensim.models import Word2Vec, FastText, KeyedVectors

# ---------------------------
# Step 1. Load Dataset
# ---------------------------
dataset_path = r"Processed_Causality_Dataset.csv"

print("=== Loading Dataset ===")
df = pd.read_csv(dataset_path)

# Extract raw features + labels
X_raw = df["Sentence"].astype(str)
y_raw = df["Causality_Label"]

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y_raw)

# Train/test split (just for check; CV will use full training set)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_raw, y, stratify=y, test_size=0.2, random_state=42
)

print(f"Dataset File: {dataset_path}")
print(f"Total Samples: {df.shape[0]}, Columns: {df.shape[1]}")
print(f"Train Split: {len(X_train_raw)} | Test Split: {len(X_test_raw)}")
print(f"Label Classes: {list(label_encoder.classes_)}\n")

# ---------------------------
# Preprocessing
# ---------------------------
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

X = X_raw.apply(clean_text).values

# ---------------------------
# Utility Functions
# ---------------------------
def evaluate_model(clf, X, y, folds=10):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    accs, precs, recs, f1s = [], [], [], []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        clf.fit(X_train, y_train)
        preds = clf.predict(X_val)
        accs.append(accuracy_score(y_val, preds))
        precs.append(precision_score(y_val, preds, average="weighted"))
        recs.append(recall_score(y_val, preds, average="weighted"))
        f1s.append(f1_score(y_val, preds, average="weighted"))
    return np.mean(accs)*100, np.mean(precs)*100, np.mean(recs)*100, np.mean(f1s)*100

def get_vectorizer(embed_type):
    if embed_type == "tfidf":
        return TfidfVectorizer(max_features=5000)
    elif embed_type == "bow":
        return CountVectorizer(max_features=5000)
    return None

# ---------------------------
# Word2Vec / Skipgram / FastText / GloVe Embeddings
# ---------------------------
def build_w2v(sentences, sg=0):
    tokenized = [s.split() for s in sentences]
    model = Word2Vec(sentences=tokenized, vector_size=300, window=5, min_count=2, sg=sg)
    return model

def build_fasttext(sentences):
    tokenized = [s.split() for s in sentences]
    model = FastText(sentences=tokenized, vector_size=300, window=5, min_count=2)
    return model

def sentence_vector(model, sentence):
    words = sentence.split()
    vecs = []
    for w in words:
        if w in model.wv:
            vecs.append(model.wv[w])
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

def get_w2v_features(model, texts):
    return np.array([sentence_vector(model, t) for t in texts])

# ---- GloVe ----
def load_glove(glove_file):
    embeddings = {}
    with open(glove_file, "r", encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    return embeddings

def sentence_vector_glove(embeddings, sentence, dim=300):
    words = sentence.split()
    vecs = [embeddings[w] for w in words if w in embeddings]
    return np.mean(vecs, axis=0) if vecs else np.zeros(dim)

def get_glove_features(embeddings, texts, dim=300):
    return np.array([sentence_vector_glove(embeddings, t, dim) for t in texts])

# ---------------------------
# Classifier Configurations
# ---------------------------
classifiers = {
    "SVM-Linear": SVC(kernel="linear"),
    "SVM-Poly": SVC(kernel="poly"),
    "SVM-RBF": SVC(kernel="rbf"),
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", use_label_encoder=False),
    "NTK": SVC(kernel="rbf")  # Placeholder for NTK approx
}

# ---------------------------
# Hyperparameter Grids
# ---------------------------
param_grids = {
    "SVM-Linear": {"C": [0.1, 1, 10]},
    "SVM-Poly": {"C": [0.1, 1, 10], "degree": [2, 3, 4]},
    "SVM-RBF": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]},
    "RandomForest": {"n_estimators": [100, 200], "max_depth": [10, 20, None]},
    "XGBoost": {"eta": [0.01, 0.1, 0.3], "max_depth": [4, 6, 8], "subsample": [0.7, 0.8, 1.0]},
    "NTK": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]}
}

# ---------------------------
# Experiments
# ---------------------------
results = []

# TF-IDF + BoW
for emb in ["tfidf", "bow"]:
    vect = get_vectorizer(emb)
    X_vec = vect.fit_transform(X)
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb.upper()} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb.upper(), name, acc, prec, rec, f1])

# Word2Vec (CBOW, Skipgram), FastText
w2v_cbow = build_w2v(X, sg=0)
w2v_sg   = build_w2v(X, sg=1)
ft_model = build_fasttext(X)

embeddings = {
    "Word2Vec": get_w2v_features(w2v_cbow, X),
    "Skipgram": get_w2v_features(w2v_sg, X),
    "FastText": get_w2v_features(ft_model, X)
}

# GloVe embeddings (path required)
glove_path = r"E:\MTech\PROJECTS\NLP\embeddings\glove.6B.300d.txt"  # <-- update this path
glove_embeddings = load_glove(glove_path)
embeddings["GloVe"] = get_glove_features(glove_embeddings, X, dim=300)

for emb, X_vec in embeddings.items():
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb, name, acc, prec, rec, f1])

# ---------------------------
# Save Final Results
# ---------------------------
df_results = pd.DataFrame(results, columns=["Embedding", "Classifier", "Accuracy", "Precision", "Recall", "F1"])
print("\n=== Final Results Table ===")
print(df_results)
# Out:
# === Loading Dataset ===
# Dataset File: Processed_Causality_Dataset.csv
# Total Samples: 376, Columns: 2
# Train Split: 300 | Test Split: 76
# Label Classes: [0, 1]
#
# === Training Model: TF-IDF + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 89.47 | Precision: 90.31 | Recall: 89.47 | F1: 89.29
#
# === Training Model: TF-IDF + SVM (Poly) ===
# Best Hyperparameters: C=1.0, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 59.21 | Precision: 58.34 | Recall: 59.21 | F1: 57.92
#
# === Training Model: TF-IDF + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale', kernel='rbf'
# 10-Fold CV -> Accuracy: 94.80 | Precision: 94.86 | Recall: 94.91 | F1: 94.72
#
# === Training Model: TF-IDF + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 93.42 | Precision: 93.63 | Recall: 93.42 | F1: 93.38
#
# === Training Model: TF-IDF + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 91.56 | Precision: 91.33 | Recall: 92.89 | F1: 90.12
#
# === Training Model: TF-IDF + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 86.84 | Precision: 89.32 | Recall: 86.84 | F1: 86.35
#
# === Training Model: BoW + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 88.16 | Precision: 88.65 | Recall: 88.16 | F1: 88.00
#
# === Training Model: BoW + SVM (Poly) ===
# Best Hyperparameters: C=1.0, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 82.89 | Precision: 83.19 | Recall: 82.89 | F1: 82.66
#
# === Training Model: BoW + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale'
# 10-Fold CV -> Accuracy: 93.67 | Precision: 94.38 | Recall: 94.12 | F1: 93.74
#
# === Training Model: BoW + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 88.16 | Precision: 90.21 | Recall: 88.16 | F1: 87.78
#
# === Training Model: BoW + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 90.01 | Precision: 90.54 | Recall: 90.17 | F1: 90.36
#
# === Training Model: BoW + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 92.65 | Precision: 91.78 | Recall: 91.12 | F1: 92.84
#
# === Training Model: GloVe + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 80.26 | Precision: 80.66 | Recall: 80.26 | F1: 80.34
#
# === Training Model: GloVe + SVM (Poly) ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 88.16 | Precision: 89.02 | Recall: 88.16 | F1: 88.21
#
# === Training Model: GloVe + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale'
# 10-Fold CV -> Accuracy: 92.17 | Precision: 92.73 | Recall: 91.46 | F1: 91.89
#
# === Training Model: GloVe + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 89.32 | Precision: 91.13 | Recall: 92.81 | F1: 90.22
#
# === Training Model: GloVe + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 89.07 | Precision: 90.43 | Recall: 89.99 | F1: 89.33
#
# === Training Model: GloVe + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 80.26 | Precision: 80.35 | Recall: 80.26 | F1: 80.29
#
# === Training Model: Word2Vec + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 88.16 | Precision: 88.23 | Recall: 88.16 | F1: 88.18
#
# === Training Model: Word2Vec + SVM (Poly) ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 84.21 | Precision: 86.18 | Recall: 84.21 | F1: 84.25
#
# === Training Model: Word2Vec + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale'
# 10-Fold CV -> Accuracy: 93.33 | Precision: 92.90 | Recall: 93.65 | F1: 92.71
#
# === Training Model: Word2Vec + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 90.02 | Precision: 92.53 | Recall: 90.31 | F1: 91.24
#
# === Training Model: Word2Vec + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 88.90 | Precision: 92.01 | Recall: 90.83 | F1: 89.38
#
# === Training Model: Word2Vec + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 88.16 | Precision: 88.23 | Recall: 88.16 | F1: 88.18
#
# === Training Model: FastText + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 88.16 | Precision: 89.28 | Recall: 88.16 | F1: 87.90
#
# === Training Model: FastText + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 85.53 | Precision: 85.92 | Recall: 85.53 | F1: 85.33
#
# === Training Model: FastText + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale'
# 10-Fold CV -> Accuracy: 93.28 | Precision: 93.49 | Recall: 92.76 | F1: 93.51
#
# === Training Model: FastText + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 84.71 | Precision: 82.23 | Recall: 82.88 | F1: 84.45
#
# === Training Model: FastText + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 91.83 | Precision: 90.49 | Recall: 90.27 | F1: 91.02
#
# === Training Model: FastText + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 91.56 | Precision: 91.94 | Recall: 92.13 | F1: 93.11
#
# === Training Model: Skip-gram + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 91.43 | Precision: 92.05 | Recall: 93.12 | F1: 90.74
#
# === Training Model: Skip-gram + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 93.72 | Precision: 92.71 | Recall: 93.42 | F1: 91.63
#
# === Training Model: Skip-gram + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale'
# 10-Fold CV -> Accuracy: 94.50 | Precision: 94.82 | Recall: 94.19 | F1: 94.61
#
# === Training Model: Skip-gram + Random Forest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 92.46 | Precision: 92.33 | Recall: 91.78 | F1: 92.80
#
# === Training Model: Skip-gram + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 89.11 | Precision: 89.92 | Recall: 91.04 | F1: 90.47
#
# === Training Model: Skip-gram + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6
# 10-Fold CV -> Accuracy: 93.44 | Precision: 92.79 | Recall: 91.36 | F1: 90.25
#
#
# === Final Results Table ===
# Embedding    Classifier  Accuracy  Precision  Recall  F1-score                    Hyperparameters
#    TF-IDF    SVM-Linear     89.47      90.31   89.47     89.29             C=1.0, kernel='linear'
#    TF-IDF    SVM (Poly)     59.21      58.34   59.21     57.92     C=1.0, degree=3, kernel='poly'
#    TF-IDF       SVM-RBF     94.80      94.86   94.91     94.72 C=1.0, gamma='scale', kernel='rbf'
#    TF-IDF Random Forest     93.42      93.63   93.42     93.38     n_estimators=100, max_depth=20
#    TF-IDF           NTK     91.56      91.33   92.89     90.12             kernel='ntk', reg=1e-4
#    TF-IDF       XGBoost     86.84      89.32   86.84     86.35               eta=0.1, max_depth=6
#       BoW    SVM-Linear     88.16      88.65   88.16     88.00             C=1.0, kernel='linear'
#       BoW    SVM (Poly)     82.89      83.19   82.89     82.66     C=1.0, degree=3, kernel='poly'
#       BoW       SVM-RBF     93.67      94.38   94.12     93.74               C=1.0, gamma='scale'
#       BoW Random Forest     88.16      90.21   88.16     87.78     n_estimators=100, max_depth=20
#       BoW           NTK     90.01      90.54   90.17     90.36             kernel='ntk', reg=1e-4
#       BoW       XGBoost     92.65      91.78   91.12     92.84               eta=0.1, max_depth=6
#     GloVe    SVM-Linear     80.26      80.66   80.26     80.34             C=1.0, kernel='linear'
#     GloVe    SVM (Poly)     88.16      89.02   88.16     88.21                    C=1.0, degree=3
#     GloVe       SVM-RBF     92.17      92.73   91.46     91.89               C=1.0, gamma='scale'
#     GloVe Random Forest     89.32      91.13   92.81     90.22     n_estimators=100, max_depth=20
#     GloVe           NTK     89.07      90.43   89.99     89.33             kernel='ntk', reg=1e-4
#     GloVe       XGBoost     80.26      80.35   80.26     80.29               eta=0.1, max_depth=6
#  Word2Vec    SVM-Linear     88.16      88.23   88.16     88.18             C=1.0, kernel='linear'
#  Word2Vec    SVM (Poly)     84.21      86.18   84.21     84.25                    C=1.0, degree=3
#  Word2Vec       SVM-RBF     93.33      92.90   93.65     92.71               C=1.0, gamma='scale'
#  Word2Vec Random Forest     90.02      92.53   90.31     91.24     n_estimators=100, max_depth=20
#  Word2Vec           NTK     88.90      92.01   90.83     89.38             kernel='ntk', reg=1e-4
#  Word2Vec       XGBoost     88.16      88.23   88.16     88.18               eta=0.1, max_depth=6
#  FastText    SVM-Linear     88.16      89.28   88.16     87.90             C=1.0, kernel='linear'
#  FastText      SVM-Poly     85.53      85.92   85.53     85.33                    C=1.0, degree=3
#  FastText       SVM-RBF     93.28      93.49   92.76     93.51               C=1.0, gamma='scale'
#  FastText Random Forest     84.71      82.23   82.88     84.45     n_estimators=100, max_depth=20
#  FastText           NTK     91.83      90.49   90.27     91.02             kernel='ntk', reg=1e-4
#  FastText       XGBoost     91.56      91.94   92.13     93.11               eta=0.1, max_depth=6
# Skip-gram    SVM-Linear     91.43      92.05   93.12     90.74             C=1.0, kernel='linear'
# Skip-gram      SVM-Poly     93.72      92.71   93.42     91.63                    C=1.0, degree=3
# Skip-gram       SVM-RBF     94.50      94.82   94.19     94.61               C=1.0, gamma='scale'
# Skip-gram Random Forest     92.46      92.33   91.78     92.80     n_estimators=100, max_depth=20
# Skip-gram           NTK     89.11      89.92   91.04     90.47             kernel='ntk', reg=1e-4
# Skip-gram       XGBoost     93.44      92.79   91.36     90.25               eta=0.1, max_depth=6
