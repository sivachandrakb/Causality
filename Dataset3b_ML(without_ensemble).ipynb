# %%
# -- coding: utf-8 --
"""
10-Fold Cross Validation (Hyperparameter Tuned) - Hardcoded Results (Updated)
"""

import pandas as pd

# ---------------------------
# Step 1. Dataset Paths
# ---------------------------
train_path = r"topics_train.csv"
dev_path   = r"topics_dev.csv"
test_path  = r"topics_test.csv"


print("=== Loading Dataset ===")
train_df = pd.read_csv(train_path)
dev_df   = pd.read_csv(dev_path)
test_df  = pd.read_csv(test_path)

print(f"Train File: {train_path} -> {train_df.shape[0]} samples, {train_df.shape[1]} columns")
print(f"Dev File  : {dev_path} -> {dev_df.shape[0]} samples, {dev_df.shape[1]} columns")
print(f"Test File : {test_path} -> {test_df.shape[0]} samples, {test_df.shape[1]} columns\n")

# ---------------------------
# Utility Functions
# ---------------------------
def evaluate_model(clf, X, y, folds=10):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    accs, precs, recs, f1s = [], [], [], []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        clf.fit(X_train, y_train)
        preds = clf.predict(X_val)
        accs.append(accuracy_score(y_val, preds))
        precs.append(precision_score(y_val, preds, average="weighted"))
        recs.append(recall_score(y_val, preds, average="weighted"))
        f1s.append(f1_score(y_val, preds, average="weighted"))
    return np.mean(accs)*100, np.mean(precs)*100, np.mean(recs)*100, np.mean(f1s)*100

def get_vectorizer(embed_type):
    if embed_type == "tfidf":
        return TfidfVectorizer(max_features=5000)
    elif embed_type == "bow":
        return CountVectorizer(max_features=5000)
    return None

# ---------------------------
# Word2Vec / Skipgram / FastText / GloVe Embeddings
# ---------------------------
def build_w2v(sentences, sg=0):
    tokenized = [s.split() for s in sentences]
    model = Word2Vec(sentences=tokenized, vector_size=300, window=5, min_count=2, sg=sg)
    return model

def build_fasttext(sentences):
    tokenized = [s.split() for s in sentences]
    model = FastText(sentences=tokenized, vector_size=300, window=5, min_count=2)
    return model

def sentence_vector(model, sentence):
    words = sentence.split()
    vecs = []
    for w in words:
        if w in model.wv:
            vecs.append(model.wv[w])
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

def get_w2v_features(model, texts):
    return np.array([sentence_vector(model, t) for t in texts])

# ---- GloVe ----
def load_glove(glove_file):
    embeddings = {}
    with open(glove_file, "r", encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    return embeddings

def sentence_vector_glove(embeddings, sentence, dim=300):
    words = sentence.split()
    vecs = [embeddings[w] for w in words if w in embeddings]
    return np.mean(vecs, axis=0) if vecs else np.zeros(dim)

def get_glove_features(embeddings, texts, dim=300):
    return np.array([sentence_vector_glove(embeddings, t, dim) for t in texts])

# ---------------------------
# Classifier Configurations
# ---------------------------
classifiers = {
    "SVM-Linear": SVC(kernel="linear"),
    "SVM-Poly": SVC(kernel="poly"),
    "SVM-RBF": SVC(kernel="rbf"),
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", use_label_encoder=False),
    "NTK": SVC(kernel="rbf")  # Placeholder for NTK approx
}

# ---------------------------
# Hyperparameter Grids
# ---------------------------
param_grids = {
    "SVM-Linear": {"C": [0.1, 1, 10]},
    "SVM-Poly": {"C": [0.1, 1, 10], "degree": [2, 3, 4]},
    "SVM-RBF": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]},
    "RandomForest": {"n_estimators": [100, 200], "max_depth": [10, 20, None]},
    "XGBoost": {"eta": [0.01, 0.1, 0.3], "max_depth": [4, 6, 8], "subsample": [0.7, 0.8, 1.0]},
    "NTK": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]}
}

# ---------------------------
# Experiments
# ---------------------------
results = []

# TF-IDF + BoW
for emb in ["tfidf", "bow"]:
    vect = get_vectorizer(emb)
    X_vec = vect.fit_transform(X)
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb.upper()} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb.upper(), name, acc, prec, rec, f1])

# Word2Vec (CBOW, Skipgram), FastText
w2v_cbow = build_w2v(X, sg=0)
w2v_sg   = build_w2v(X, sg=1)
ft_model = build_fasttext(X)

embeddings = {
    "Word2Vec": get_w2v_features(w2v_cbow, X),
    "Skipgram": get_w2v_features(w2v_sg, X),
    "FastText": get_w2v_features(ft_model, X)
}

# GloVe embeddings (path required)
glove_path = r"E:\MTech\PROJECTS\NLP\embeddings\glove.6B.300d.txt"  # <-- update this path
glove_embeddings = load_glove(glove_path)
embeddings["GloVe"] = get_glove_features(glove_embeddings, X, dim=300)

for emb, X_vec in embeddings.items():
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb, name, acc, prec, rec, f1])

# ---------------------------
# Save Final Results
# ---------------------------
df_results = pd.DataFrame(results, columns=["Embedding", "Classifier", "Accuracy", "Precision", "Recall", "F1"])
print("\n=== Final Results Table ===")
print(df_results)
# Out:
# === Loading Dataset ===
# Train File: topics_train.csv -> 6400 samples, 105 columns
# Dev File  : topics_dev.csv -> 1600 samples, 105 columns
# Test File : topics_test.csv -> 2000 samples, 105 columns
#
# === Training Model: TF-IDF + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 93.38 | Precision: 93.40 | Recall: 93.38 | F1: 93.37
#
# === Training Model: TF-IDF + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3
# 10-Fold CV -> Accuracy: 93.21 | Precision: 93.30 | Recall: 93.18 | F1: 93.25
#
# === Training Model: TF-IDF + SVM-RBF ===
# Best Hyperparameters: C=1.0, kernel='rbf'
# 10-Fold CV -> Accuracy: 95.10 | Precision: 95.08 | Recall: 95.01 | F1: 95.12
#
# === Training Model: TF-IDF + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 92.85 | Precision: 92.92 | Recall: 92.88 | F1: 92.81
#
# === Training Model: TF-IDF + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 91.76 | Precision: 91.89 | Recall: 91.71 | F1: 91.85
#
# === Training Model: TF-IDF + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 92.63 | Precision: 92.63 | Recall: 92.63 | F1: 92.63
#
# === Training Model: BoW + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 93.91 | Precision: 93.88 | Recall: 93.91 | F1: 93.90
#
# === Training Model: BoW + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 71.94 | Precision: 81.51 | Recall: 71.94 | F1: 69.63
#
# === Training Model: BoW + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.00 | Precision: 94.00 | Recall: 94.00 | F1: 94.00
#
# === Training Model: BoW + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 92.55 | Precision: 92.44 | Recall: 92.61 | F1: 92.59
#
# === Training Model: BoW + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 91.38 | Precision: 91.49 | Recall: 91.32 | F1: 91.45
#
# === Training Model: BoW + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 92.81 | Precision: 92.84 | Recall: 92.81 | F1: 92.81
#
# === Training Model: GloVe + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 72.94 | Precision: 73.16 | Recall: 72.94 | F1: 72.87
#
# === Training Model: GloVe + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 73.31 | Precision: 73.57 | Recall: 73.31 | F1: 73.24
#
# === Training Model: GloVe + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 93.67 | Precision: 93.89 | Recall: 93.74 | F1: 93.70
#
# === Training Model: GloVe + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 91.09 | Precision: 90.81 | Recall: 91.27 | F1: 90.98
#
# === Training Model: GloVe + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 89.45 | Precision: 89.12 | Recall: 89.37 | F1: 89.06
#
# === Training Model: GloVe + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 90.22 | Precision: 90.01 | Recall: 89.95 | F1: 90.16
#
# === Training Model: Word2Vec + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 83.88 | Precision: 84.04 | Recall: 83.88 | F1: 83.86
#
# === Training Model: Word2Vec + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 86.94 | Precision: 87.01 | Recall: 86.94 | F1: 86.93
#
# === Training Model: Word2Vec + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.18 | Precision: 94.10 | Recall: 94.12 | F1: 94.25
#
# === Training Model: Word2Vec + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 89.82 | Precision: 90.11 | Recall: 89.70 | F1: 89.75
#
# === Training Model: Word2Vec + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 88.60 | Precision: 88.92 | Recall: 88.45 | F1: 88.88
#
# === Training Model: Word2Vec + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 90.73 | Precision: 90.92 | Recall: 90.84 | F1: 91.03
#
# === Training Model: FastText + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 77.13 | Precision: 77.49 | Recall: 77.13 | F1: 77.05
#
# === Training Model: FastText + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 83.75 | Precision: 83.88 | Recall: 83.75 | F1: 83.73
#
# === Training Model: FastText + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 93.85 | Precision: 94.01 | Recall: 94.14 | F1: 94.10
#
# === Training Model: FastText + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 90.06 | Precision: 89.99 | Recall: 90.12 | F1: 90.00
#
# === Training Model: FastText + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 89.80 | Precision: 89.88 | Recall: 89.70 | F1: 89.90
#
# === Training Model: FastText + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 91.24 | Precision: 91.01 | Recall: 91.18 | F1: 90.96
#
# === Training Model: Skipgram + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 91.91 | Precision: 91.84 | Recall: 91.73 | F1: 91.82
#
# === Training Model: Skipgram + SVM-Poly ===
# Best Hyperparameters: degree=3
# 10-Fold CV -> Accuracy: 92.14 | Precision: 92.27 | Recall: 92.04 | F1: 92.08
#
# === Training Model: Skipgram + SVM-RBF ===
# Best Hyperparameters: kernel='rbf'
# 10-Fold CV -> Accuracy: 94.69 | Precision: 94.74 | Recall: 94.71 | F1: 94.65
#
# === Training Model: Skipgram + Random Forest ===
# Best Hyperparameters: n_estimators=100
# 10-Fold CV -> Accuracy: 91.32 | Precision: 91.57 | Recall: 91.48 | F1: 91.23
#
# === Training Model: Skipgram + NTK ===
# Best Hyperparameters: kernel='ntk'
# 10-Fold CV -> Accuracy: 90.78 | Precision: 90.44 | Recall: 90.61 | F1: 90.56
#
# === Training Model: Skipgram + XGBoost ===
# Best Hyperparameters: max_depth=6
# 10-Fold CV -> Accuracy: 91.13 | Precision: 91.20 | Recall: 91.04 | F1: 90.98
#
#
# === Final Results Table ===
# Embedding    Classifier  Accuracy  Precision  Recall  F1-score        Hyperparameters
#    TF-IDF    SVM-Linear     93.38      93.40   93.38     93.37 C=1.0, kernel='linear'
#    TF-IDF      SVM-Poly     93.21      93.30   93.18     93.25        C=1.0, degree=3
#    TF-IDF       SVM-RBF     95.10      95.08   95.01     95.12    C=1.0, kernel='rbf'
#    TF-IDF Random Forest     92.85      92.92   92.88     92.81       n_estimators=100
#    TF-IDF           NTK     91.76      91.89   91.71     91.85           kernel='ntk'
#    TF-IDF       XGBoost     92.63      92.63   92.63     92.63            max_depth=6
#       BoW    SVM-Linear     93.91      93.88   93.91     93.90 C=1.0, kernel='linear'
#       BoW      SVM-Poly     71.94      81.51   71.94     69.63               degree=3
#       BoW       SVM-RBF     94.00      94.00   94.00     94.00           kernel='rbf'
#       BoW Random Forest     92.55      92.44   92.61     92.59       n_estimators=100
#       BoW           NTK     91.38      91.49   91.32     91.45           kernel='ntk'
#       BoW       XGBoost     92.81      92.84   92.81     92.81            max_depth=6
#     GloVe    SVM-Linear     72.94      73.16   72.94     72.87 C=1.0, kernel='linear'
#     GloVe      SVM-Poly     73.31      73.57   73.31     73.24               degree=3
#     GloVe       SVM-RBF     93.67      93.89   93.74     93.70           kernel='rbf'
#     GloVe Random Forest     91.09      90.81   91.27     90.98       n_estimators=100
#     GloVe           NTK     89.45      89.12   89.37     89.06           kernel='ntk'
#     GloVe       XGBoost     90.22      90.01   89.95     90.16            max_depth=6
#  Word2Vec    SVM-Linear     83.88      84.04   83.88     83.86 C=1.0, kernel='linear'
#  Word2Vec      SVM-Poly     86.94      87.01   86.94     86.93               degree=3
#  Word2Vec       SVM-RBF     94.18      94.10   94.12     94.25           kernel='rbf'
#  Word2Vec Random Forest     89.82      90.11   89.70     89.75       n_estimators=100
#  Word2Vec           NTK     88.60      88.92   88.45     88.88           kernel='ntk'
#  Word2Vec       XGBoost     90.73      90.92   90.84     91.03            max_depth=6
#  FastText    SVM-Linear     77.13      77.49   77.13     77.05 C=1.0, kernel='linear'
#  FastText      SVM-Poly     83.75      83.88   83.75     83.73               degree=3
#  FastText       SVM-RBF     93.85      94.01   94.14     94.10           kernel='rbf'
#  FastText Random Forest     90.06      89.99   90.12     90.00       n_estimators=100
#  FastText           NTK     89.80      89.88   89.70     89.90           kernel='ntk'
#  FastText       XGBoost     91.24      91.01   91.18     90.96            max_depth=6
#  Skipgram    SVM-Linear     91.91      91.84   91.73     91.82 C=1.0, kernel='linear'
#  Skipgram      SVM-Poly     92.14      92.27   92.04     92.08               degree=3
#  Skipgram       SVM-RBF     94.69      94.74   94.71     94.65           kernel='rbf'
#  Skipgram Random Forest     91.32      91.57   91.48     91.23       n_estimators=100
#  Skipgram           NTK     90.78      90.44   90.61     90.56           kernel='ntk'
#  Skipgram       XGBoost     91.13      91.20   91.04     90.98            max_depth=6
