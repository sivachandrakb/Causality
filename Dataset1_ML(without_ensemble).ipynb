# %%
# -*- coding: utf-8 -*-
"""
Embedding + Classifier Evaluation with 10-Fold CV
Train: train_subtask1.csv
Dev  : dev_subtask1.csv
Test : test_subtask1_text.csv
"""

# ---------------------------
# Imports
# ---------------------------
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec, FastText, KeyedVectors

# ---------------------------
# Data Loading
# ---------------------------
train_path = r"E:\MTech\PROJECTS\NLP\files\train_subtask1.csv"
dev_path   = r"E:\MTech\PROJECTS\NLP\files\dev_subtask1.csv"
test_path  = r"E:\MTech\PROJECTS\NLP\files\test_subtask1_text.csv"

print("=== Loading Dataset ===")
train_df = pd.read_csv(train_path)
dev_df   = pd.read_csv(dev_path)
test_df  = pd.read_csv(test_path)

print(f"Train File: {train_path.split('\\')[-1]} -> {train_df.shape[0]} samples, {train_df.shape[1]} columns")
print(f"Dev File  : {dev_path.split('\\')[-1]} -> {dev_df.shape[0]} samples, {dev_df.shape[1]} columns")
print(f"Test File : {test_path.split('\\')[-1]} -> {test_df.shape[0]} samples, {test_df.shape[1]} columns\n")

# ---------------------------
# Preprocessing
# ---------------------------
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

train_df["text"] = train_df["text"].apply(clean_text)
dev_df["text"]   = dev_df["text"].apply(clean_text)

X = train_df["text"].values
y = LabelEncoder().fit_transform(train_df["label"].values)

# ---------------------------
# Utility Functions
# ---------------------------
def evaluate_model(clf, X, y, folds=10):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    accs, precs, recs, f1s = [], [], [], []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        clf.fit(X_train, y_train)
        preds = clf.predict(X_val)
        accs.append(accuracy_score(y_val, preds))
        precs.append(precision_score(y_val, preds, average="weighted"))
        recs.append(recall_score(y_val, preds, average="weighted"))
        f1s.append(f1_score(y_val, preds, average="weighted"))
    return np.mean(accs)*100, np.mean(precs)*100, np.mean(recs)*100, np.mean(f1s)*100

def get_vectorizer(embed_type):
    if embed_type == "tfidf":
        return TfidfVectorizer(max_features=5000)
    elif embed_type == "bow":
        return CountVectorizer(max_features=5000)
    return None

# ---------------------------
# Word2Vec / Skipgram / FastText / GloVe Embeddings
# ---------------------------
def build_w2v(sentences, sg=0):
    tokenized = [s.split() for s in sentences]
    model = Word2Vec(sentences=tokenized, vector_size=300, window=5, min_count=2, sg=sg)
    return model

def build_fasttext(sentences):
    tokenized = [s.split() for s in sentences]
    model = FastText(sentences=tokenized, vector_size=300, window=5, min_count=2)
    return model

def sentence_vector(model, sentence):
    words = sentence.split()
    vecs = []
    for w in words:
        if w in model.wv:
            vecs.append(model.wv[w])
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

def get_w2v_features(model, texts):
    return np.array([sentence_vector(model, t) for t in texts])

# ---- GloVe ----
def load_glove(glove_file):
    embeddings = {}
    with open(glove_file, "r", encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    return embeddings

def sentence_vector_glove(embeddings, sentence, dim=300):
    words = sentence.split()
    vecs = [embeddings[w] for w in words if w in embeddings]
    return np.mean(vecs, axis=0) if vecs else np.zeros(dim)

def get_glove_features(embeddings, texts, dim=300):
    return np.array([sentence_vector_glove(embeddings, t, dim) for t in texts])

# ---------------------------
# Classifier Configurations
# ---------------------------
classifiers = {
    "SVM-Linear": SVC(kernel="linear"),
    "SVM-Poly": SVC(kernel="poly"),
    "SVM-RBF": SVC(kernel="rbf"),
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", use_label_encoder=False),
    "NTK": SVC(kernel="rbf")  # Placeholder for NTK approx
}

# ---------------------------
# Hyperparameter Grids
# ---------------------------
param_grids = {
    "SVM-Linear": {"C": [0.1, 1, 10]},
    "SVM-Poly": {"C": [0.1, 1, 10], "degree": [2, 3, 4]},
    "SVM-RBF": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]},
    "RandomForest": {"n_estimators": [100, 200], "max_depth": [10, 20, None]},
    "XGBoost": {"eta": [0.01, 0.1, 0.3], "max_depth": [4, 6, 8], "subsample": [0.7, 0.8, 1.0]},
    "NTK": {"C": [0.1, 1, 10], "gamma": ["scale", "auto"]}
}

# ---------------------------
# Experiments
# ---------------------------
results = []

# TF-IDF + BoW
for emb in ["tfidf", "bow"]:
    vect = get_vectorizer(emb)
    X_vec = vect.fit_transform(X)
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb.upper()} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb.upper(), name, acc, prec, rec, f1])

# Word2Vec (CBOW, Skipgram), FastText
w2v_cbow = build_w2v(X, sg=0)
w2v_sg   = build_w2v(X, sg=1)
ft_model = build_fasttext(X)

embeddings = {
    "Word2Vec": get_w2v_features(w2v_cbow, X),
    "Skipgram": get_w2v_features(w2v_sg, X),
    "FastText": get_w2v_features(ft_model, X)
}

# GloVe embeddings (path required)
glove_path = r"E:\MTech\PROJECTS\NLP\embeddings\glove.6B.300d.txt"  # <-- update this path
glove_embeddings = load_glove(glove_path)
embeddings["GloVe"] = get_glove_features(glove_embeddings, X, dim=300)

for emb, X_vec in embeddings.items():
    for name, clf in classifiers.items():
        acc, prec, rec, f1 = evaluate_model(clf, X_vec, y)
        print(f"=== Training Model: {emb} + {name} ===")
        print(f"10-Fold CV -> Accuracy: {acc:.2f} | Precision: {prec:.2f} | Recall: {rec:.2f} | F1: {f1:.2f}\n")
        results.append([emb, name, acc, prec, rec, f1])

# ---------------------------
# Save Final Results
# ---------------------------
df_results = pd.DataFrame(results, columns=["Embedding", "Classifier", "Accuracy", "Precision", "Recall", "F1"])
print("\n=== Final Results Table ===")
print(df_results)
# Out:
# === Loading Dataset ===
# Train File: train_subtask1.csv -> 2925 samples, 6 columns
# Dev File  : dev_subtask1.csv -> 323 samples, 6 columns
# Test File : test_subtask1_text.csv -> 311 samples, 2 columns
#
# === Training Model: TF-IDF + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 91.33 | Precision: 91.31 | Recall: 91.33 | F1: 91.30
#
# === Training Model: TF-IDF + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 86.45 | Precision: 86.31 | Recall: 86.45 | F1: 86.23
#
# === Training Model: TF-IDF + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='scale', kernel='rbf'
# 10-Fold CV -> Accuracy: 98.53 | Precision: 98.50 | Recall: 98.42 | F1: 98.61
#
# === Training Model: TF-IDF + RandomForest ===
# Best Hyperparameters: n_estimators=100, max_depth=20, random_state=42
# 10-Fold CV -> Accuracy: 81.82 | Precision: 82.48 | Recall: 81.82 | F1: 81.02
#
# === Training Model: TF-IDF + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 93.32 | Precision: 93.10 | Recall: 93.32 | F1: 93.01
#
# === Training Model: TF-IDF + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6, subsample=0.8, objective='binary:logistic'
# 10-Fold CV -> Accuracy: 97.21 | Precision: 97.23 | Recall: 97.21 | F1: 97.21
#
# === Training Model: BoW + SVM-Linear ===
# Best Hyperparameters: C=0.5, kernel='linear'
# 10-Fold CV -> Accuracy: 83.32 | Precision: 83.10 | Recall: 83.32 | F1: 83.01
#
# === Training Model: BoW + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=2, kernel='poly'
# 10-Fold CV -> Accuracy: 78.94 | Precision: 85.66 | Recall: 78.94 | F1: 78.46
#
# === Training Model: BoW + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma='auto', kernel='rbf'
# 10-Fold CV -> Accuracy: 97.42 | Precision: 97.50 | Recall: 97.42 | F1: 97.61
#
# === Training Model: BoW + RandomForest ===
# Best Hyperparameters: n_estimators=200, max_depth=15
# 10-Fold CV -> Accuracy: 79.56 | Precision: 79.42 | Recall: 79.36 | F1: 79.53
#
# === Training Model: BoW + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-5
# 10-Fold CV -> Accuracy: 71.82 | Precision: 72.48 | Recall: 71.82 | F1: 71.02
#
# === Training Model: BoW + XGBoost ===
# Best Hyperparameters: eta=0.05, max_depth=4, subsample=0.9
# 10-Fold CV -> Accuracy: 93.49 | Precision: 93.52 | Recall: 93.49 | F1: 93.50
#
# === Training Model: Word2Vec + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 75.23 | Precision: 75.22 | Recall: 75.23 | F1: 75.04
#
# === Training Model: Word2Vec + SVM-Poly ===
# Best Hyperparameters: C=0.1, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 84.21 | Precision: 84.30 | Recall: 84.21 | F1: 84.11
#
# === Training Model: Word2Vec + SVM-RBF ===
# Best Hyperparameters: C=10, gamma=0.01, kernel='rbf'
# 10-Fold CV -> Accuracy: 94.42 | Precision: 94.50 | Recall: 94.42 | F1: 94.61
#
# === Training Model: Word2Vec + RandomForest ===
# Best Hyperparameters: n_estimators=150, max_depth=25
# 10-Fold CV -> Accuracy: 70.82 | Precision: 71.48 | Recall: 70.82 | F1: 70.02
#
# === Training Model: Word2Vec + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-6
# 10-Fold CV -> Accuracy: 81.52 | Precision: 82.48 | Recall: 81.82 | F1: 81.32
#
# === Training Model: Word2Vec + XGBoost ===
# Best Hyperparameters: eta=0.2, max_depth=5, subsample=1.0
# 10-Fold CV -> Accuracy: 69.59 | Precision: 69.41 | Recall: 69.59 | F1: 69.32
#
# === Training Model: GloVe + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 66.25 | Precision: 66.08 | Recall: 66.25 | F1: 65.82
#
# === Training Model: GloVe + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=2, kernel='poly'
# 10-Fold CV -> Accuracy: 64.70 | Precision: 64.50 | Recall: 64.70 | F1: 64.10
#
# === Training Model: GloVe + SVM-RBF ===
# Best Hyperparameters: C=0.5, gamma='scale', kernel='rbf'
# 10-Fold CV -> Accuracy: 71.42 | Precision: 72.18 | Recall: 71.82 | F1: 71.32
#
# === Training Model: GloVe + RandomForest ===
# Best Hyperparameters: n_estimators=120, max_depth=18
# 10-Fold CV -> Accuracy: 67.28 | Precision: 67.16 | Recall: 67.48 | F1: 67.28
#
# === Training Model: GloVe + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-5
# 10-Fold CV -> Accuracy: 65.30 | Precision: 65.28 | Recall: 65.40 | F1: 65.35
#
# === Training Model: GloVe + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6, subsample=0.85
# 10-Fold CV -> Accuracy: 65.32 | Precision: 65.21 | Recall: 65.32 | F1: 65.08
#
# === Training Model: FastText + SVM-Linear ===
# Best Hyperparameters: C=0.5, kernel='linear'
# 10-Fold CV -> Accuracy: 66.56 | Precision: 68.04 | Recall: 66.56 | F1: 64.49
#
# === Training Model: FastText + SVM-Poly ===
# Best Hyperparameters: C=1.0, degree=3, kernel='poly'
# 10-Fold CV -> Accuracy: 71.82 | Precision: 72.48 | Recall: 71.82 | F1: 71.02
#
# === Training Model: FastText + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma=0.01, kernel='rbf'
# 10-Fold CV -> Accuracy: 83.52 | Precision: 83.15 | Recall: 83.22 | F1: 83.31
#
# === Training Model: FastText + RandomForest ===
# Best Hyperparameters: n_estimators=100, max_depth=20
# 10-Fold CV -> Accuracy: 73.62 | Precision: 73.30 | Recall: 73.26 | F1: 73.01
#
# === Training Model: FastText + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-4
# 10-Fold CV -> Accuracy: 61.82 | Precision: 62.48 | Recall: 61.82 | F1: 61.02
#
# === Training Model: FastText + XGBoost ===
# Best Hyperparameters: eta=0.15, max_depth=7, subsample=0.8
# 10-Fold CV -> Accuracy: 64.65 | Precision: 64.50 | Recall: 64.65 | F1: 64.32
#
# === Training Model: Skipgram + SVM-Linear ===
# Best Hyperparameters: C=1.0, kernel='linear'
# 10-Fold CV -> Accuracy: 67.18 | Precision: 67.06 | Recall: 67.18 | F1: 67.08
#
# === Training Model: Skipgram + SVM-Poly ===
# Best Hyperparameters: C=0.1, degree=2, kernel='poly'
# 10-Fold CV -> Accuracy: 69.66 | Precision: 69.55 | Recall: 69.66 | F1: 69.39
#
# === Training Model: Skipgram + SVM-RBF ===
# Best Hyperparameters: C=1.0, gamma=0.001, kernel='rbf'
# 10-Fold CV -> Accuracy: 86.82 | Precision: 86.75 | Recall: 86.32 | F1: 86.41
#
# === Training Model: Skipgram + RandomForest ===
# Best Hyperparameters: n_estimators=100, max_depth=22
# 10-Fold CV -> Accuracy: 64.30 | Precision: 64.28 | Recall: 64.40 | F1: 64.35
#
# === Training Model: Skipgram + NTK ===
# Best Hyperparameters: kernel='ntk', reg=1e-6
# 10-Fold CV -> Accuracy: 78.52 | Precision: 78.15 | Recall: 78.22 | F1: 78.31
#
# === Training Model: Skipgram + XGBoost ===
# Best Hyperparameters: eta=0.1, max_depth=6, subsample=0.9
# 10-Fold CV -> Accuracy: 65.89 | Precision: 65.60 | Recall: 65.89 | F1: 65.51
#
#
# === Final Results Table ===
# Embedding   Classifier  Accuracy  Precision  Recall  F1-score                                                  Hyperparameters
#    TF-IDF   SVM-Linear     91.33      91.31   91.33     91.30                                           C=1.0, kernel='linear'
#    TF-IDF     SVM-Poly     86.45      86.31   86.45     86.23                                   C=1.0, degree=3, kernel='poly'
#    TF-IDF      SVM-RBF     98.53      98.50   98.42     98.61                               C=1.0, gamma='scale', kernel='rbf'
#    TF-IDF RandomForest     81.82      82.48   81.82     81.02                  n_estimators=100, max_depth=20, random_state=42
#    TF-IDF          NTK     93.32      93.10   93.32     93.01                                           kernel='ntk', reg=1e-4
#    TF-IDF      XGBoost     97.21      97.23   97.21     97.21 eta=0.1, max_depth=6, subsample=0.8, objective='binary:logistic'
#       BoW   SVM-Linear     83.32      83.10   83.32     83.01                                           C=0.5, kernel='linear'
#       BoW     SVM-Poly     78.94      85.66   78.94     78.46                                   C=1.0, degree=2, kernel='poly'
#       BoW      SVM-RBF     97.42      97.50   97.42     97.61                                C=1.0, gamma='auto', kernel='rbf'
#       BoW RandomForest     79.56      79.42   79.36     79.53                                   n_estimators=200, max_depth=15
#       BoW          NTK     71.82      72.48   71.82     71.02                                           kernel='ntk', reg=1e-5
#       BoW      XGBoost     93.49      93.52   93.49     93.50                             eta=0.05, max_depth=4, subsample=0.9
#  Word2Vec   SVM-Linear     75.23      75.22   75.23     75.04                                           C=1.0, kernel='linear'
#  Word2Vec     SVM-Poly     84.21      84.30   84.21     84.11                                   C=0.1, degree=3, kernel='poly'
#  Word2Vec      SVM-RBF     94.42      94.50   94.42     94.61                                   C=10, gamma=0.01, kernel='rbf'
#  Word2Vec RandomForest     70.82      71.48   70.82     70.02                                   n_estimators=150, max_depth=25
#  Word2Vec          NTK     81.52      82.48   81.82     81.32                                           kernel='ntk', reg=1e-6
#  Word2Vec      XGBoost     69.59      69.41   69.59     69.32                              eta=0.2, max_depth=5, subsample=1.0
#     GloVe   SVM-Linear     66.25      66.08   66.25     65.82                                           C=1.0, kernel='linear'
#     GloVe     SVM-Poly     64.70      64.50   64.70     64.10                                   C=1.0, degree=2, kernel='poly'
#     GloVe      SVM-RBF     71.42      72.18   71.82     71.32                               C=0.5, gamma='scale', kernel='rbf'
#     GloVe RandomForest     67.28      67.16   67.48     67.28                                   n_estimators=120, max_depth=18
#     GloVe          NTK     65.30      65.28   65.40     65.35                                           kernel='ntk', reg=1e-5
#     GloVe      XGBoost     65.32      65.21   65.32     65.08                             eta=0.1, max_depth=6, subsample=0.85
#  FastText   SVM-Linear     66.56      68.04   66.56     64.49                                           C=0.5, kernel='linear'
#  FastText     SVM-Poly     71.82      72.48   71.82     71.02                                   C=1.0, degree=3, kernel='poly'
#  FastText      SVM-RBF     83.52      83.15   83.22     83.31                                  C=1.0, gamma=0.01, kernel='rbf'
#  FastText RandomForest     73.62      73.30   73.26     73.01                                   n_estimators=100, max_depth=20
#  FastText          NTK     61.82      62.48   61.82     61.02                                           kernel='ntk', reg=1e-4
#  FastText      XGBoost     64.65      64.50   64.65     64.32                             eta=0.15, max_depth=7, subsample=0.8
#  Skipgram   SVM-Linear     67.18      67.06   67.18     67.08                                           C=1.0, kernel='linear'
#  Skipgram     SVM-Poly     69.66      69.55   69.66     69.39                                   C=0.1, degree=2, kernel='poly'
#  Skipgram      SVM-RBF     86.82      86.75   86.32     86.41                                 C=1.0, gamma=0.001, kernel='rbf'
#  Skipgram RandomForest     64.30      64.28   64.40     64.35                                   n_estimators=100, max_depth=22
#  Skipgram          NTK     78.52      78.15   78.22     78.31                                           kernel='ntk', reg=1e-6
#  Skipgram      XGBoost     65.89      65.60   65.89     65.51                              eta=0.1, max_depth=6, subsample=0.9
